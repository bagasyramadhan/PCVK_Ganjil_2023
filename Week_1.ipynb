# %% [markdown]
# <a href="https://colab.research.google.com/github/bagasyramadhan/PCVK_Ganjil_2023/blob/main/Week_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #langkah 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# #langkah 2

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert color to RGB
  final_frame = cv.hconcat((image, image_2))      # concatenate image
  cv2_imshow(final_frame)                         # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# #langkah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# #langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ##pertanyaan

# %% [markdown]
# **1.Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?**
#
# karena pada google colab bisa diakses melalui berbagai device dan diakses dimanapun, dan python dapat mudah diakses di google colab

# %% [markdown]
# **2.Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan?**
#
# Apakah semua library tersebut harus digunakan dalam praktikum sesi ini
# Pada praktikum langkah ke delapan, terdapat beberapa library yang digunakan dengan kegunaan masing-masing.seperti
#
# 1. **Pandas**: digunakan untuk mengidentifikasi data
#
# 2. **NumPy**: digunakan untuk mengelola data angka
#
# 3. **Matplotlib**: digunakan untuk menampilkan atau visualisasi data
#
# 4. **CV2**:digunakan untuk memproses sebuah gambar
#
# 5. **skimage**: digunakan untuk memproses visual atau gambar dengan resolusi tinggi

# %% [markdown]
# **3.pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :**![image.png](data:image/png;base64,...)
#
# **Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan**
# digunakan untuk mengatur ukuran gambar dan harus dilakukan agar ukuran bisa sesuai

# %% [markdown]
# **4.Perhatikan potongan kode progam berikut :**
#
# ![image.png](data:image/png;base64,...)
#
# **Apakah kegunaan kode [255,255,255] ? Jelaskan!**
#
# menambah pixel warna berupa garis berwana putih pada gambar

# %% [markdown]
# **5.Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!**
#
# Pixel adalah titik individual dalam sebuah gambar digital. Resolusi tinggi memiliki lebih banyak pixel dalam gambar dan menghasilkan detail yang lebih baik, sementara resolusi rendah memiliki sedikit pixel dan hasilnya kurang detail.

# %% [markdown]
# ##tugas

# %%
# Garis Vertical
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in  range (tinggi):
  image_3[y, int((lebar)/2)] = [0,0,0]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

#Garis Diagonal
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#Garis Menyilang diagonal dari image keluaran
cv.line(image_3, (0,0), (lebar, tinggi), (0,0,0))

cv.line(image_3, (400,0), (0, tinggi), (0,0,0))

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
# Gambarlah garis putih horizontal di tengah gambar dengan panjang tertentu
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (100,200):
  image_3[int(image_3.shape[0] / 2), y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
#Gambarlah sebuah kotak dari kumpulan piksel putih pada area tertentu pada gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Menentukan posisi kotak dan ukurannya
kotak_posisi_x = 120
kotak_posisi_y = 130
kotak_lebar = 150
kotak_tinggi = 90

image_3[kotak_posisi_y:kotak_posisi_y + kotak_tinggi, kotak_posisi_x:kotak_posisi_x + kotak_lebar] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
import cv2 as cv
import matplotlib.pyplot as plty

# Ganti dengan path ke file gambar Anda (KTP/SIM)
path_to_image = "KTP.jpeg"

# Baca gambar menggunakan OpenCV
image = cv.imread(path_to_image)
# Warna kotak (putih)
warna_kotak = (255, 255, 255)

# Koordinat pojok kiri atas dan kanan bawah kotak
x1 = int(lebar * 0.50)
y1 = int(tinggi * 0.25)
x2 = int(lebar * 1.35) #panjang
y2 = int(tinggi * 0.35)

# Gambar kotak putih pada gambar
cv.rectangle(image, (x1, y1), (x2, y2), warna_kotak, -1)

# Warna kotak (hitam)
warna_kotak2 = (0, 0, 0)

# Koordinat pojok kiri atas dan kanan bawah kotak
x3 = int(lebar * 0.47)
y3 = int(tinggi * 0.5)
x4 = int(lebar * 1.35) #panjang
y4 = int(tinggi * 0.4)

# Gambar kotak putih pada gambar
cv.rectangle(image, (x3, y3), (x4, y4), warna_kotak2, -1)

# Ubah format warna gambar dari BGR menjadi RGB untuk digunakan oleh Matplotlib
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan Matplotlib
plt.imshow(image_rgb)
plt.axis('off')  # Tidak menampilkan sumbu koordinat
plt.show()
